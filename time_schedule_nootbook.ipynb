# %%
import pandas as pd
import numpy as np
import random

excel_file = '1017168_coursetimemajor_2018-04-23.xlsx'
schedule = pd.read_excel(excel_file)

# %%
#-------------------------------------------------------------
# verify or change the following value as you import a new file
#-------------------------------------------------------------

#the column that contains days of which courses are offering on
day_col = 'Days_of_week'

#the column that identifies student
stu_col = 'Key'

year = 'Class'

Start_time = 'Start_time'

End_time = 'End_time'

quarter = np.int64(20172)


#headers
cols = list(schedule)
cols.remove(day_col)


#---------
#a function that outputs course and student's information based on the row index associated with the day

#input: the row index of the current day; keep track of student's info
#output: a list of student's info except the Days_of_week info
#@staticmethod
def outputOtherInfo(row_idx, df):
    otherInfoList = []
    
    for col in cols:
        #if not col == "Days_of_week":
        otherInfoList.append(df[col][row_idx])
    return otherInfoList

# %%
#------------------------------------------------
# Filter out pre major freshmen and sophomore
#------------------------------------------------

quarter_schedule = schedule.loc[schedule['YrQtr'] == quarter]

freshmen = quarter_schedule.loc[quarter_schedule[year] == np.int64(1)]
sophomore = quarter_schedule.loc[quarter_schedule[year] == np.int64(2)]

premajor = [freshmen, sophomore]

# %%
#------------------
# random sampling for each class now is freshmen or change freshmen to sophomore
#------------------

sample_table = []

unique_list = []

# function to get unique values
def unique(students):
    # traverse for all elements
    for x in students:
        
        # check if exists in unique_list or not
        if x not in unique_list:
            unique_list.append(x)

#--------------------------
#first get a unique list of students key
for each_class in premajor:
    
    unique_list = []
    
    unique(each_class[stu_col])
    
    #--------------------------------------
    #then do random sampling within the list
    
    sample_students = []
    
    sample_students = random.sample(unique_list, int(len(unique_list)/ 2))

    #------------------------------------------------------
    #then selecting the rows that contain sampled students key

    for student in sample_students:
        something = each_class.loc[each_class[stu_col] == student]
        sample_table.append(something)
        
output_table = pd.concat(sample_table)
final_table = output_table.reset_index(drop=True)

# %%
final_table
# Out:
#           Key  Class  YrQtr  Campus          Course_title     Course  \
# 0     1620090      1  20172       0  PRECALCULUS           MATH  120
# 1     1730217      1  20172       2  INTRO ACADEM WRIT     T CORE101
# 2     1730217      1  20172       2  INTRO TO BUSINESS     T BUS 101
# 3     1617500      1  20172       2  CS PRINCIPLES         TCSS  101
# 4     1617500      1  20172       2  AMERICAN LIT          T LIT 210
# 5     1617500      1  20172       2  AMERICAN CULTURES     T AMST210
# 6     1658096      1  20172       0  INTRO TO GEOL SCI     ESS   101
# 7     1658096      1  20172       2  COMMUNITY DEVEL       T URB 235
# 8     1658096      1  20172       2  ROOTS OF BLUES        T ARTS210
# 9     1615554      1  20172       2  PSYCH URBAN LIVING    TPSYCH341
# 10    1615554      1  20172       2  INTRO ACADEM WRIT     T CORE101
# 11    1615554      1  20172       2  INTRO LIT & ENVIRO    T LIT 237
# 12    1612943      1  20172       1  ARTS IN CONTEXT       BISCLA380
# 13    1612943      1  20172       1  HEALTH STATISTICS     B HLTH215
# 14    1612943      1  20172       1  NATURAL WORLD 3       B CORE119
# 15    1618115      1  20172       1  VIS LIT PFRM ART 3    B CORE120
# 16    1618115      1  20172       1  INTRO TO PHILOSOPHY   BIS   193
# 17    1618115      1  20172       1  INTRO TO BUS STATS    B BUS 215
# 18    1730192      1  20172       0  GEOG WORLD ECONOMY    GEOG  208
# 19    1730192      1  20172       0  POL ECON OF AFRICA    JSIS A362
# 20    1618967      1  20172       0  SUP STDY SEL FIELDS   GEN ST391
# 21    1618967      1  20172       0  BASIC PHOTO           ART   140
# 22    1618967      1  20172       0  THE CULTURE CONCEPT   ANTH  208
# 23    1618967      1  20172       0  INTRO TO PSYCH        PSYCH 101
# 24    1611692      1  20172       0  COMPOSITION: LIT      ENGL  111
# 25    1611692      1  20172       0  INTERMEDIATE TAGALOG  TAGLG 203
# 26    1611692      1  20172       0  GENERAL CHEMISTRY     CHEM  152
# 27     832112      1  20172       0  ASTRONOMY             ASTR  101
# 28    1663406      1  20172       1  ALG & QUANT REAS      B MATH121
# 29    1663406      1  20172       1  INDVDUALS & SOC 3     B CORE118
# ...       ...    ...    ...     ...                   ...        ...
# 6315  1655170      2  20172       0  ELEMNTS STAT METHOD   STAT  311
# 6316  1655170      2  20172       0  COMPUTER PRGRMNG II   CSE   143
# 6317  1627852      2  20172       0  APPREC OF ARCH I      ARCH  150
# 6318  1627852      2  20172       0  CALC ANYL GEOM III    MATH  126
# 6319  1627852      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 6320  1627852      2  20172       0  COMPUTER PRGRMNG I    CSE   142
# 6321  1653080      2  20172       0  CALC ANYL GEOM III    MATH  126
# 6322  1653080      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 6323  1653080      2  20172       0  GENERAL CHEMISTRY     CHEM  142
# 6324  1655802      2  20172       0  ELEM NORWEGIAN        NORW  103
# 6325  1655802      2  20172       0  HUMAN RIGHTS LAW      LSJ   321
# 6326  1655802      2  20172       0  BUSINESS &ECON CALC   MATH  112
# 6327  1619855      2  20172       0  INTRO BIOLOGY         BIOL  180
# 6328  1619855      2  20172       0  GENERAL CHEMISTRY     CHEM  162
# 6329  1619855      2  20172       0  OUTBREAK              EPI   201
# 6330  1617492      2  20172       0  BLK WOMEN IN DRAMA    AFRAM 320
# 6331  1617492      2  20172       0  INTO PUB POL & GOV    PUBPOL201
# 6332  1617492      2  20172       0  POL ECON OF AFRICA    JSIS A362
# 6333  1657276      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 6334  1657276      2  20172       0  STAT FOR SOC SCI      STAT  221
# 6335  1657276      2  20172       0  SWED LIT&CLTRL HIST   SCAND 156
# 6336  1619260      2  20172       0  APPREC OF ARCH I      ARCH  150
# 6337  1619260      2  20172       0  AFRAM POLIT THOUGHT   AFRAM 370
# 6338  1619260      2  20172       0  LIVING WITH VOLCANO   ESS   106
# 6339  1619260      2  20172       0  UNDERGRAD SEMINAR     GEN ST297
# 6340  1619260      2  20172       0  THE CULTURE CONCEPT   ANTH  208
# 6341  1621156      2  20172       0  COMPOSITION: LIT      ENGL  111
# 6342  1621156      2  20172       0  BIOETHICS TOPICS      B H   201
# 6343  1621156      2  20172       0  SURV HIST OF U S      HSTAA 101
# 6344  1621156      2  20172       0  HURRICANE SCIENCE     ATM S 103
#
#      Dept_abbrev  Course_no Section_id Days_of_week  Start_time  End_time  \
# 0         MATH          120        B         M WR          1830      1950
# 1         T CORE        101        E         M W F          930      1050
# 2         T BUS         101        A          T R          1015      1220
# 3         TCSS          101        A         M W           1015      1220
# 4         T LIT         210        A         M W           1330      1535
# 5         T AMST        210        C          T R           800      1005
# 6         ESS           101        A         M W F         1230      1320
# 7         T URB         235        A          T R          1250      1455
# 8         T ARTS        210        A          T R          1720      1925
# 9         TPSYCH        341        A         M W F          930      1050
# 10        T CORE        101        B         M W F         1100      1220
# 11        T LIT         237        A         M W F          800       920
# 12        BISCLA        380        A         M W           1100      1300
# 13        B HLTH        215        B         M W            845      1045
# 14        B CORE        119        C         M W           1315      1515
# 15        B CORE        120        A          T R          1315      1515
# 16        BIS           193        A          T R          1100      1300
# 17        B BUS         215        A         M W           1100      1300
# 18        GEOG          208        A         M W           1430      1550
# 19        JSIS A        362        A          T R          1530      1720
# 20        GEN ST        391        N         M W           1230      1320
# 21        ART           140        C         M W           1430      1720
# 22        ANTH          208        A          T R          1330      1520
# 23        PSYCH         101        A         MTWRF          930      1020
# 24        ENGL          111        K         MTWR          1130      1220
# 25        TAGLG         203        A         MTWRF         1230      1320
# 26        CHEM          152        B         M W F         1330      1420
# 27        ASTR          101        A         M W           1100      1220
# 28        B MATH        121        B         M W           1315      1515
# 29        B CORE        118        A         M             1100      1300
# ...          ...        ...        ...          ...         ...       ...
# 6315      STAT          311        A         M W F         1430      1520
# 6316      CSE           143        A         M W F         1230      1320
# 6317      ARCH          150        A          T R          1200      1320
# 6318      MATH          126        B         M W F         1030      1120
# 6319      ENGL          131        B7        M W           1130      1320
# 6320      CSE           142        B         M W F         1330      1420
# 6321      MATH          126        F         M W F         1430      1520
# 6322      ENGL          131        A4         T R           830      1020
# 6323      CHEM          142        A         M W F          830       920
# 6324      NORW          103        A         MTWRF          930      1020
# 6325      LSJ           321        A         M W           1330      1450
# 6326      MATH          112        A         M W F         1130      1220
# 6327      BIOL          180        A         MTWRF         1330      1420
# 6328      CHEM          162        C         M W F         1430      1520
# 6329      EPI           201        A          T R          1030      1150
# 6330      AFRAM         320        A          T R          1330      1520
# 6331      PUBPOL        201        A          T R          1130      1250
# 6332      JSIS A        362        A          T R          1530      1720
# 6333      ENGL          131        V         M W           1330      1520
# 6334      STAT          221        A         M W F          930      1020
# 6335      SCAND         156        A          T R          1330      1520
# 6336      ARCH          150        A          T R          1200      1320
# 6337      AFRAM         370        A          T R           930      1120
# 6338      ESS           106        A         M W F          930      1020
# 6339      GEN ST        297        F           W           1430      1620
# 6340      ANTH          208        A          T R          1330      1520
# 6341      ENGL          111        K         MTWR          1130      1220
# 6342      B H           201        A          T            1430      1620
# 6343      HSTAA         101        A          T R          1230      1420
# 6344      ATM S         103        A         M W F         1030      1120
#
#           Location Building Room_number meeting_type           Major1 Major2  \
# 0     DEN  258         DEN          258           LC  0-PRE HS-00-0-0    NaN
# 1     ADMCGWP101       ADMC    GWP101             LC  2-TPRMAJ-00-0-0    NaN
# 2     JOY  206         JOY          206           LC  2-TPRMAJ-00-0-0    NaN
# 3     DOU  101         DOU          101           LC    2-TPRE-00-0-0    NaN
# 4     DOU  201         DOU          201           LC    2-TPRE-00-0-0    NaN
# 5     DOU  260         DOU          260           LC    2-TPRE-00-0-0    NaN
# 6     KNE  130         KNE          130           LC    2-TPRE-00-0-0    NaN
# 7     DOU  280         DOU          280           LC    2-TPRE-00-0-0    NaN
# 8     JOY  001         JOY            1           LC    2-TPRE-00-0-0    NaN
# 9     MAT  214         MAT          214           LC    2-TPRE-00-0-0    NaN
# 10    ADMCGWP101       ADMC    GWP101             LC    2-TPRE-00-0-0    NaN
# 11    DOU  201         DOU          201           LC    2-TPRE-00-0-0    NaN
# 12    UW2  305         UW2          305           LC   1-B PRE-00-0-0    NaN
# 13    UW1  120         UW1          120           LC   1-B PRE-00-0-0    NaN
# 14    UW2  205         UW2          205           LC   1-B PRE-00-0-0    NaN
# 15    UW1  060         UW1           60           LC   1-B PRE-00-0-0    NaN
# 16    UW1  041         UW1           41           LC   1-B PRE-00-0-0    NaN
# 17    UW1  010         UW1           10           LC   1-B PRE-00-0-0    NaN
# 18    SIG  134         SIG          134           LC    0-XA&S-00-0-0    NaN
# 19    MGH  074         MGH           74           LC    0-XA&S-00-0-0    NaN
# 20    ARC  147         ARC          147           LC  0-PRE PH-00-0-0    NaN
# 21    ART  116         ART          116           ST  0-PRE PH-00-0-0    NaN
# 22    MGH  389         MGH          389           LC  0-PRE PH-00-0-0    NaN
# 23    KNE  120         KNE          120           LC  0-PRE PH-00-0-0    NaN
# 24    PAA A212         PAA     A212               LC  0-PREMAJ-00-0-0    NaN
# 25    SIG  227         SIG          227           LC  0-PREMAJ-00-0-0    NaN
# 26    BAG  131         BAG          131           LC  0-PREMAJ-00-0-0    NaN
# 27    ARC  147         ARC          147           LC     0-EEP-00-0-0    NaN
# 28    UW2  340         UW2          340           LC   1-B PRE-00-0-0    NaN
# 29    UW2  040         UW2           40           LC   1-B PRE-00-0-0    NaN
# ...            ...      ...         ...          ...              ...    ...
# 6315  ARC  147         ARC          147           LC  0-PRESCI-00-0-0    NaN
# 6316  GUG  220         GUG          220           LC  0-PRESCI-00-0-0    NaN
# 6317  KNE  130         KNE          130           LC  0-PRESCI-00-0-0    NaN
# 6318  CDH  109         CDH          109           LC  0-PRESCI-00-0-0    NaN
# 6319  LOW  112         LOW          112           LC  0-PRESCI-00-0-0    NaN
# 6320  KNE  120         KNE          120           LC  0-PRESCI-00-0-0    NaN
# 6321  AND  223         AND          223           LC  0-PRESCI-00-0-0    NaN
# 6322  THO  231         THO          231           LC  0-PRESCI-00-0-0    NaN
# 6323  GUG  220         GUG          220           LC  0-PRESCI-00-0-0    NaN
# 6324  EEB  025         EEB           25           LC   0-EPRMJ-00-0-0    NaN
# 6325  GWN  201         GWN          201           LC   0-EPRMJ-00-0-0    NaN
# 6326  EEB  105         EEB          105           LC   0-EPRMJ-00-0-0    NaN
# 6327  KNE  130         KNE          130           LC  0-PRE HS-00-0-0    NaN
# 6328  BAG  131         BAG          131           LC  0-PRE HS-00-0-0    NaN
# 6329  HST T625         HST     T625               LC  0-PRE HS-00-0-0    NaN
# 6330  CMU  226         CMU          226           LC  0-PRE HS-00-0-0    NaN
# 6331  OTB  014         OTB           14           LC  0-PRE HS-00-0-0    NaN
# 6332  MGH  074         MGH           74           LC  0-PRE HS-00-0-0    NaN
# 6333  PAR  313         PAR          313           LC  0-PREMAJ-00-0-0    NaN
# 6334  SAV  260         SAV          260           LC  0-PREMAJ-00-0-0    NaN
# 6335  SMI  211         SMI          211           LC  0-PREMAJ-00-0-0    NaN
# 6336  KNE  130         KNE          130           LC     0-COM-00-1-1    NaN
# 6337  CMU  226         CMU          226           LC     0-COM-00-1-1    NaN
# 6338  KNE  110         KNE          110           LC     0-COM-00-1-1    NaN
# 6339  SIG  224         SIG          224           SM     0-COM-00-1-1    NaN
# 6340  MGH  389         MGH          389           LC     0-COM-00-1-1    NaN
# 6341  PAA A212         PAA     A212               LC  0-PRE HS-00-0-0    NaN
# 6342  AND  223         AND          223           LC  0-PRE HS-00-0-0    NaN
# 6343  AND  223         AND          223           LC  0-PRE HS-00-0-0    NaN
# 6344  KNE  130         KNE          130           LC  0-PRE HS-00-0-0    NaN
#
#      Major3
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ...     ...
# 6315    NaN
# 6316    NaN
# 6317    NaN
# 6318    NaN
# 6319    NaN
# 6320    NaN
# 6321    NaN
# 6322    NaN
# 6323    NaN
# 6324    NaN
# 6325    NaN
# 6326    NaN
# 6327    NaN
# 6328    NaN
# 6329    NaN
# 6330    NaN
# 6331    NaN
# 6332    NaN
# 6333    NaN
# 6334    NaN
# 6335    NaN
# 6336    NaN
# 6337    NaN
# 6338    NaN
# 6339    NaN
# 6340    NaN
# 6341    NaN
# 6342    NaN
# 6343    NaN
# 6344    NaN
#
# [6345 rows x 19 columns]

# %%
#-----------------------
# separating days column
#-----------------------

week = final_table[day_col]

#create a new table to store separated courses' information
new_Table = []

new_headers = ['Day'] + cols


#loop through the days that are in each cell
#combine corresponding class and student info into a new list
#append the list into the new table

for idx, days in enumerate(week):
    for day in days:
        if not day.isspace():
            
            #create a new list for each day
            each_day = []
            each_day.append(day)
            each_day = each_day + outputOtherInfo(idx, final_table)
            new_Table.append(each_day)

#-------
#output the new Table into a dataframe with columns 
new_schedule = pd.DataFrame(new_Table, columns = list(new_headers))
new_schedule

#----------
#sort new_schedule by Student_ID 1, then by Day 0, then by Pm, finally by start time 7
sorted_schedule = new_schedule.sort_values(by=[stu_col, 'Day', Start_time])
new_schedule = sorted_schedule.reset_index(drop=True)
new_schedule
# Out:
#       Day      Key  Class  YrQtr  Campus          Course_title     Course  \
# 0       W   516344      2  20172       0  CONCERT BAND          MUSEN 309
# 1       F   532044      2  20172       0  CALC ANALYT GEOM I    MATH  124
# 2       F   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 3       M   532044      2  20172       0  CALC ANALYT GEOM I    MATH  124
# 4       M   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 5       M   532044      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 6       R   532044      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 7       T   532044      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 8       W   532044      2  20172       0  CALC ANALYT GEOM I    MATH  124
# 9       W   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 10      W   532044      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 11      F   540914      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 12      F   540914      2  20172       0  INTRO TO GEOL SCI     ESS   101
# 13      M   540914      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 14      M   540914      2  20172       0  INTRO TO GEOL SCI     ESS   101
# 15      R   540914      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 16      T   540914      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 17      W   540914      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 18      W   540914      2  20172       0  INTRO TO GEOL SCI     ESS   101
# 19      R   541031      1  20172       1  INDVDUALS & SOC 3     B CORE118
# 20      T   541031      1  20172       1  INDVDUALS & SOC 3     B CORE118
# 21      F   640959      2  20172       0  GENERAL CHEMISTRY     CHEM  142
# 22      F   640959      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 23      F   640959      2  20172       0  ELECTROMAGNETISM      PHYS  122
# 24      M   640959      2  20172       0  GENERAL CHEMISTRY     CHEM  142
# 25      M   640959      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 26      M   640959      2  20172       0  ELECTROMAGNETISM      PHYS  122
# 27      R   640959      2  20172       0  INTRO TO PSYCH        PSYCH 101
# 28      R   640959      2  20172       0  ELECTROMAGNETISM      PHYS  122
# 29      T   640959      2  20172       0  INTRO TO PSYCH        PSYCH 101
# ...    ..      ...    ...    ...     ...                   ...        ...
# 15356   T  1740491      2  20172       1  LATINO HLTH&CULTURE   B HLTH222
# 15357   W  1740491      2  20172       1  HEALTH STATISTICS     B MATH215
# 15358   M  1740493      1  20172       1  GLOBAL HLTH & FILM    B HLTH199
# 15359   M  1740493      1  20172       1  INTERDISC WRITING     B WRIT134
# 15360   R  1740493      1  20172       1  INTRO TO PSYCH        BIS   170
# 15361   T  1740493      1  20172       1  INTRO TO PSYCH        BIS   170
# 15362   W  1740493      1  20172       1  GLOBAL HLTH & FILM    B HLTH199
# 15363   W  1740493      1  20172       1  INTERDISC WRITING     B WRIT134
# 15364   F  1740576      2  20172       2  INTRO LIT & ENVIRO    T LIT 237
# 15365   F  1740576      2  20172       2  MANAGERIAL ACCT       T ACCT230
# 15366   M  1740576      2  20172       2  INTRO LIT & ENVIRO    T LIT 237
# 15367   M  1740576      2  20172       2  MANAGERIAL ACCT       T ACCT230
# 15368   R  1740576      2  20172       2  INTRO MICROECONOMICS  TECON 200
# 15369   T  1740576      2  20172       2  INTRO MICROECONOMICS  TECON 200
# 15370   W  1740576      2  20172       2  INTRO LIT & ENVIRO    T LIT 237
# 15371   W  1740576      2  20172       2  MANAGERIAL ACCT       T ACCT230
# 15372   M  1740646      1  20172       1  INTRO TO BUS STATS    B BUS 215
# 15373   M  1740646      1  20172       1  INTR ART TECHNIQUES   BISIA 283
# 15374   R  1740646      1  20172       1  INTRO MICROECON       B BUS 220
# 15375   T  1740646      1  20172       1  INTRO MICROECON       B BUS 220
# 15376   W  1740646      1  20172       1  INTRO TO BUS STATS    B BUS 215
# 15377   W  1740646      1  20172       1  INTR ART TECHNIQUES   BISIA 283
# 15378   F  9140181      2  20172       0  ELEMENTARY HINDI      HINDI 103
# 15379   M  9140181      2  20172       0  ELEMENTARY HINDI      HINDI 103
# 15380   R  9140181      2  20172       0  ELEMENTARY HINDI      HINDI 103
# 15381   T  9140181      2  20172       0  ELEMENTARY HINDI      HINDI 103
# 15382   W  9140181      2  20172       0  ELEMENTARY HINDI      HINDI 103
# 15383   M  9817838      2  20172       0  TOPICS IN AMER HIST   HSTAA 490
# 15384   W  9817838      2  20172       0  TOPICS IN AMER HIST   HSTAA 490
# 15385   W  9817838      2  20172       0  LECTURES APPL STAT    BIOST 111
#
#       Dept_abbrev  Course_no Section_id  Start_time  End_time      Location  \
# 0          MUSEN         309        A          1900      2050  MNY  268
# 1          MATH          124        A           930      1020  EEB  105
# 2          ATM S         103        A          1030      1120  KNE  130
# 3          MATH          124        A           930      1020  EEB  105
# 4          ATM S         103        A          1030      1120  KNE  130
# 5          ENGL          131        I          1130      1220  THO  334
# 6          ENGL          131        I          1130      1220  THO  334
# 7          ENGL          131        I          1130      1220  THO  334
# 8          MATH          124        A           930      1020  EEB  105
# 9          ATM S         103        A          1030      1120  KNE  130
# 10         ENGL          131        I          1130      1220  THO  334
# 11         PSYCH         101        B          1030      1120  KNE  120
# 12         ESS           101        A          1230      1320  KNE  130
# 13         PSYCH         101        B          1030      1120  KNE  120
# 14         ESS           101        A          1230      1320  KNE  130
# 15         PSYCH         101        B          1030      1120  KNE  120
# 16         PSYCH         101        B          1030      1120  KNE  120
# 17         PSYCH         101        B          1030      1120  KNE  120
# 18         ESS           101        A          1230      1320  KNE  130
# 19         B CORE        118        G           845      1045  UW1  261
# 20         B CORE        118        G           845      1045  UW1  261
# 21         CHEM          142        A           830       920  GUG  220
# 22         PSYCH         101        B          1030      1120  KNE  120
# 23         PHYS          122        B          1230      1320  PAA A102
# 24         CHEM          142        A           830       920  GUG  220
# 25         PSYCH         101        B          1030      1120  KNE  120
# 26         PHYS          122        B          1230      1320  PAA A102
# 27         PSYCH         101        B          1030      1120  KNE  120
# 28         PHYS          122        B          1700      1820  KNE  220
# 29         PSYCH         101        B          1030      1120  KNE  120
# ...           ...        ...        ...         ...       ...           ...
# 15356      B HLTH        222        A          1315      1515  UW1  261
# 15357      B MATH        215        B           845      1045  UW1  120
# 15358      B HLTH        199        A           845      1045  UW1  261
# 15359      B WRIT        134        C          1530      1730  UW1  261
# 15360      BIS           170        A           845      1045  UW1  202
# 15361      BIS           170        A           845      1045  UW1  202
# 15362      B HLTH        199        A           845      1045  UW1  261
# 15363      B WRIT        134        C          1530      1730  UW1  261
# 15364      T LIT         237        A           800       920  DOU  201
# 15365      T ACCT        230        C          1100      1220  DOU  260
# 15366      T LIT         237        A           800       920  DOU  201
# 15367      T ACCT        230        C          1100      1220  DOU  260
# 15368      TECON         200        B           800      1005  JOY  113
# 15369      TECON         200        B           800      1005  JOY  113
# 15370      T LIT         237        A           800       920  DOU  201
# 15371      T ACCT        230        C          1100      1220  DOU  260
# 15372      B BUS         215        B          1315      1515  UW1  010
# 15373      BISIA         283        B          1530      1730  DISC 165 B
# 15374      B BUS         220        A          1315      1515  UWBB 240
# 15375      B BUS         220        A          1315      1515  UWBB 240
# 15376      B BUS         215        B          1315      1515  UW1  010
# 15377      BISIA         283        B          1530      1730  DISC 165 B
# 15378      HINDI         103        A           930      1020  SAV  157
# 15379      HINDI         103        A           930      1020  SAV  157
# 15380      HINDI         103        A           930      1020  SAV  157
# 15381      HINDI         103        A           930      1020  SAV  157
# 15382      HINDI         103        A           930      1020  SAV  157
# 15383      HSTAA         490        A          1030      1220  MGH  278
# 15384      HSTAA         490        A          1030      1220  MGH  278
# 15385      BIOST         111        A          1330      1420  HSD D209
#
#       Building Room_number meeting_type           Major1 Major2  Major3
# 0         MNY          268           LC  0-PREMAJ-00-0-0    NaN     NaN
# 1         EEB          105           LC  0-PREMAJ-00-0-0    NaN     NaN
# 2         KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 3         EEB          105           LC  0-PREMAJ-00-0-0    NaN     NaN
# 4         KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 5         THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 6         THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 7         THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 8         EEB          105           LC  0-PREMAJ-00-0-0    NaN     NaN
# 9         KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 10        THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 11        KNE          120           LC   0-PSOCS-00-0-0    NaN     NaN
# 12        KNE          130           LC   0-PSOCS-00-0-0    NaN     NaN
# 13        KNE          120           LC   0-PSOCS-00-0-0    NaN     NaN
# 14        KNE          130           LC   0-PSOCS-00-0-0    NaN     NaN
# 15        KNE          120           LC   0-PSOCS-00-0-0    NaN     NaN
# 16        KNE          120           LC   0-PSOCS-00-0-0    NaN     NaN
# 17        KNE          120           LC   0-PSOCS-00-0-0    NaN     NaN
# 18        KNE          130           LC   0-PSOCS-00-0-0    NaN     NaN
# 19        UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 20        UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 21        GUG          220           LC  0-PRESCI-00-0-0    NaN     NaN
# 22        KNE          120           LC  0-PRESCI-00-0-0    NaN     NaN
# 23        PAA     A102               LC  0-PRESCI-00-0-0    NaN     NaN
# 24        GUG          220           LC  0-PRESCI-00-0-0    NaN     NaN
# 25        KNE          120           LC  0-PRESCI-00-0-0    NaN     NaN
# 26        PAA     A102               LC  0-PRESCI-00-0-0    NaN     NaN
# 27        KNE          120           LC  0-PRESCI-00-0-0    NaN     NaN
# 28        KNE          220           LC  0-PRESCI-00-0-0    NaN     NaN
# 29        KNE          120           LC  0-PRESCI-00-0-0    NaN     NaN
# ...        ...         ...          ...              ...    ...     ...
# 15356     UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 15357     UW1          120           LC   1-B PRE-00-0-0    NaN     NaN
# 15358     UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 15359     UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 15360     UW1          202           LC   1-B PRE-00-0-0    NaN     NaN
# 15361     UW1          202           LC   1-B PRE-00-0-0    NaN     NaN
# 15362     UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 15363     UW1          261           LC   1-B PRE-00-0-0    NaN     NaN
# 15364     DOU          201           LC    2-TPRE-00-0-0    NaN     NaN
# 15365     DOU          260           LC    2-TPRE-00-0-0    NaN     NaN
# 15366     DOU          201           LC    2-TPRE-00-0-0    NaN     NaN
# 15367     DOU          260           LC    2-TPRE-00-0-0    NaN     NaN
# 15368     JOY          113           LC    2-TPRE-00-0-0    NaN     NaN
# 15369     JOY          113           LC    2-TPRE-00-0-0    NaN     NaN
# 15370     DOU          201           LC    2-TPRE-00-0-0    NaN     NaN
# 15371     DOU          260           LC    2-TPRE-00-0-0    NaN     NaN
# 15372     UW1           10           LC   1-B PRE-00-0-0    NaN     NaN
# 15373     DISC     165 B             LC   1-B PRE-00-0-0    NaN     NaN
# 15374     UWBB         240           LC   1-B PRE-00-0-0    NaN     NaN
# 15375     UWBB         240           LC   1-B PRE-00-0-0    NaN     NaN
# 15376     UW1           10           LC   1-B PRE-00-0-0    NaN     NaN
# 15377     DISC     165 B             LC   1-B PRE-00-0-0    NaN     NaN
# 15378     SAV          157           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15379     SAV          157           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15380     SAV          157           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15381     SAV          157           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15382     SAV          157           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15383     MGH          278           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15384     MGH          278           LC  0-PREMAJ-00-0-0    NaN     NaN
# 15385     HSD     D209               LC  0-PREMAJ-00-0-0    NaN     NaN
#
# [15386 rows x 19 columns]

# %%
#---------------------------------
# take out non-consecutive classes 
#---------------------------------

cons_class_table = []
cols = list(new_schedule)
timegapList = [0]

#verify if the student id and the day are the same
#return the time gap between classes if the same
# return 999 as time gap if not the same
def gapTimeWithNextClass(clas1, idx):
    new_idx = idx + 1 
    timegap = 0
    
    #next class
    clas2 = [new_schedule[stu_col][new_idx], new_schedule['Day'][new_idx], new_schedule[Start_time][new_idx]]
    
    if (clas1[0] == clas2[0] and clas1[1] == clas2[1]):
        timegap = clas2[2] - clas1[2]
    else:
        timegap = 999
    
    timegapList.append(timegap)
    
    return timegap        
    
#
def create_cons_class_table(clas1_idx):
    clas2_idx = clas1_idx + 1
    
    clas1_info = outputOtherInfo(i, new_schedule)
    clas2_info = outputOtherInfo(clas2_idx, new_schedule)

    cons_class_table.append(clas1_info)
    cons_class_table.append(clas2_info)

    
for i in range(new_schedule.shape[0]-1):
    class1 = [new_schedule[stu_col][i], new_schedule['Day'][i], new_schedule[End_time][i]]
    
    time = gapTimeWithNextClass(class1, i)
        
    # if there is 10 mins gap in between classes
    if (time == 10 or time == 50):
        create_cons_class_table(i)
    
new_schedule['TimeGap'] = timegapList

cons_schedule = pd.DataFrame(cons_class_table, columns = list(new_headers))
cons_schedule
# Out:
#      Day      Key  Class  YrQtr  Campus          Course_title     Course  \
# 0      F   532044      2  20172       0  CALC ANALYT GEOM I    MATH  124
# 1      F   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 2      M   532044      2  20172       0  CALC ANALYT GEOM I    MATH  124
# 3      M   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 4      M   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 5      M   532044      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 6      W   532044      2  20172       0  CALC ANALYT GEOM I    MATH  124
# 7      W   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 8      W   532044      2  20172       0  HURRICANE SCIENCE     ATM S 103
# 9      W   532044      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 10     F   841730      2  20172       0  ELEMENTARY SPANISH    SPAN  103
# 11     F   841730      2  20172       0  INTRO INTERNATL REL   POL S 203
# 12     M   841730      2  20172       0  ELEMENTARY SPANISH    SPAN  103
# 13     M   841730      2  20172       0  INTRO INTERNATL REL   POL S 203
# 14     W   841730      2  20172       0  ELEMENTARY SPANISH    SPAN  103
# 15     W   841730      2  20172       0  INTRO INTERNATL REL   POL S 203
# 16     R   924329      2  20172       0  RECRTNL FISHERIES     FISH  260
# 17     R   924329      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 18     T   924329      2  20172       0  RECRTNL FISHERIES     FISH  260
# 19     T   924329      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 20     F   940952      2  20172       0  INTRO MACROECON       ECON  201
# 21     F   940952      2  20172       0  HISTORY OF JAZZ       MUSIC 131
# 22     M   940952      2  20172       0  INTRO MACROECON       ECON  201
# 23     M   940952      2  20172       0  HISTORY OF JAZZ       MUSIC 131
# 24     R   940952      2  20172       0  INTRO MACROECON       ECON  201
# 25     R   940952      2  20172       0  HISTORY OF JAZZ       MUSIC 131
# 26     T   940952      2  20172       0  INTRO MACROECON       ECON  201
# 27     T   940952      2  20172       0  HISTORY OF JAZZ       MUSIC 131
# 28     W   940952      2  20172       0  INTRO MACROECON       ECON  201
# 29     W   940952      2  20172       0  HISTORY OF JAZZ       MUSIC 131
# ...   ..      ...    ...    ...     ...                   ...        ...
# 5208   W  1731341      2  20172       0  WRITING FRM SOURCES   ENGL  103
# 5209   W  1731341      2  20172       0  AMER POP SONG         MUSIC 162
# 5210   R  1740005      2  20172       2  SHAKESPEARE           T LIT 343
# 5211   R  1740005      2  20172       2  PRECALCULUS           TMATH 120
# 5212   T  1740005      2  20172       2  SHAKESPEARE           T LIT 343
# 5213   T  1740005      2  20172       2  PRECALCULUS           TMATH 120
# 5214   F  1740224      1  20172       2  URBAN PLANNING        T URB 220
# 5215   F  1740224      1  20172       2  URBAN SOC & CULTURE   T URB 210
# 5216   M  1740224      1  20172       2  URBAN PLANNING        T URB 220
# 5217   M  1740224      1  20172       2  URBAN SOC & CULTURE   T URB 210
# 5218   W  1740224      1  20172       2  URBAN PLANNING        T URB 220
# 5219   W  1740224      1  20172       2  URBAN SOC & CULTURE   T URB 210
# 5220   M  1740291      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5221   M  1740291      2  20172       0  INTRO TO GEOL SCI     ESS   101
# 5222   W  1740291      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5223   W  1740291      2  20172       0  INTRO TO GEOL SCI     ESS   101
# 5224   M  1740292      1  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5225   M  1740292      1  20172       0  INTRO TO ENV HEALTH   ENV H 311
# 5226   R  1740292      1  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5227   R  1740292      1  20172       0  OUTBREAK              EPI   201
# 5228   T  1740292      1  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5229   T  1740292      1  20172       0  OUTBREAK              EPI   201
# 5230   W  1740292      1  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5231   W  1740292      1  20172       0  INTRO TO ENV HEALTH   ENV H 311
# 5232   R  1740293      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5233   R  1740293      2  20172       0  FORESTS AND SOCIETY   ESRM  101
# 5234   T  1740293      2  20172       0  COMPOSITN: EXPOSITN   ENGL  131
# 5235   T  1740293      2  20172       0  FORESTS AND SOCIETY   ESRM  101
# 5236   W  1740293      2  20172       0  FORESTS AND SOCIETY   ESRM  101
# 5237   W  1740293      2  20172       0  UNDERGRAD SEMINAR     GEN ST297
#
#      Dept_abbrev  Course_no Section_id  Start_time  End_time      Location  \
# 0         MATH          124        A           930      1020  EEB  105
# 1         ATM S         103        A          1030      1120  KNE  130
# 2         MATH          124        A           930      1020  EEB  105
# 3         ATM S         103        A          1030      1120  KNE  130
# 4         ATM S         103        A          1030      1120  KNE  130
# 5         ENGL          131        I          1130      1220  THO  334
# 6         MATH          124        A           930      1020  EEB  105
# 7         ATM S         103        A          1030      1120  KNE  130
# 8         ATM S         103        A          1030      1120  KNE  130
# 9         ENGL          131        I          1130      1220  THO  334
# 10        SPAN          103        A           930      1020  LOW  111
# 11        POL S         203        A          1030      1120  SMI  120
# 12        SPAN          103        A           930      1020  LOW  111
# 13        POL S         203        A          1030      1120  SMI  120
# 14        SPAN          103        A           930      1020  LOW  111
# 15        POL S         203        A          1030      1120  SMI  120
# 16        FISH          260        A          1030      1220  FSH  102
# 17        ENGL          131        Q          1230      1420  THO  134
# 18        FISH          260        A          1030      1220  FSH  102
# 19        ENGL          131        Q          1230      1420  THO  134
# 20        ECON          201        J           930      1020  CDH  101
# 21        MUSIC         131        A          1030      1120  MUS  126
# 22        ECON          201        J           930      1020  CDH  101
# 23        MUSIC         131        A          1030      1120  MUS  126
# 24        ECON          201        J           930      1020  CDH  101
# 25        MUSIC         131        A          1030      1120  MUS  126
# 26        ECON          201        J           930      1020  CDH  101
# 27        MUSIC         131        A          1030      1120  MUS  126
# 28        ECON          201        J           930      1020  CDH  101
# 29        MUSIC         131        A          1030      1120  MUS  126
# ...          ...        ...        ...         ...       ...           ...
# 5208      ENGL          103        A           830       920  SAV  158
# 5209      MUSIC         162        A           930      1020  KNE  130
# 5210      T LIT         343        A          1250      1455  ADMCBHS107
# 5211      TMATH         120        F          1505      1710  JOY  106
# 5212      T LIT         343        A          1250      1455  ADMCBHS107
# 5213      TMATH         120        F          1505      1710  JOY  106
# 5214      T URB         220        A           930      1050  JOY  113
# 5215      T URB         210        A          1100      1220  DOU  280
# 5216      T URB         220        A           930      1050  JOY  113
# 5217      T URB         210        A          1100      1220  DOU  280
# 5218      T URB         220        A           930      1050  JOY  113
# 5219      T URB         210        A          1100      1220  DOU  280
# 5220      ENGL          131        I          1130      1220  THO  334
# 5221      ESS           101        A          1230      1320  KNE  130
# 5222      ENGL          131        I          1130      1220  THO  334
# 5223      ESS           101        A          1230      1320  KNE  130
# 5224      ENGL          131        A6          930      1020  MEB  245
# 5225      ENV H         311        A          1030      1120  HST T625
# 5226      ENGL          131        A6          930      1020  MEB  245
# 5227      EPI           201        A          1030      1150  HST T625
# 5228      ENGL          131        A6          930      1020  MEB  245
# 5229      EPI           201        A          1030      1150  HST T625
# 5230      ENGL          131        A6          930      1020  MEB  245
# 5231      ENV H         311        A          1030      1120  HST T625
# 5232      ENGL          131        B6         1130      1320  LOW  117
# 5233      ESRM          101        A          1330      1420  KNE  220
# 5234      ENGL          131        B6         1130      1320  LOW  117
# 5235      ESRM          101        A          1330      1420  KNE  220
# 5236      ESRM          101        A          1330      1420  KNE  220
# 5237      GEN ST        297        F          1430      1620  SIG  224
#
#      Building Room_number meeting_type           Major1 Major2  Major3
# 0        EEB          105           LC  0-PREMAJ-00-0-0    NaN     NaN
# 1        KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 2        EEB          105           LC  0-PREMAJ-00-0-0    NaN     NaN
# 3        KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 4        KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 5        THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 6        EEB          105           LC  0-PREMAJ-00-0-0    NaN     NaN
# 7        KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 8        KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 9        THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 10       LOW          111           LC     0-SIS-00-1-1    NaN     NaN
# 11       SMI          120           LC     0-SIS-00-1-1    NaN     NaN
# 12       LOW          111           LC     0-SIS-00-1-1    NaN     NaN
# 13       SMI          120           LC     0-SIS-00-1-1    NaN     NaN
# 14       LOW          111           LC     0-SIS-00-1-1    NaN     NaN
# 15       SMI          120           LC     0-SIS-00-1-1    NaN     NaN
# 16       FSH          102           LC  0-PRESCI-00-0-0    NaN     NaN
# 17       THO          134           LC  0-PRESCI-00-0-0    NaN     NaN
# 18       FSH          102           LC  0-PRESCI-00-0-0    NaN     NaN
# 19       THO          134           LC  0-PRESCI-00-0-0    NaN     NaN
# 20       CDH          101           LC  0-DESIGN-32-1-7    NaN     NaN
# 21       MUS          126           LC  0-DESIGN-32-1-7    NaN     NaN
# 22       CDH          101           LC  0-DESIGN-32-1-7    NaN     NaN
# 23       MUS          126           LC  0-DESIGN-32-1-7    NaN     NaN
# 24       CDH          101           LC  0-DESIGN-32-1-7    NaN     NaN
# 25       MUS          126           LC  0-DESIGN-32-1-7    NaN     NaN
# 26       CDH          101           LC  0-DESIGN-32-1-7    NaN     NaN
# 27       MUS          126           LC  0-DESIGN-32-1-7    NaN     NaN
# 28       CDH          101           LC  0-DESIGN-32-1-7    NaN     NaN
# 29       MUS          126           LC  0-DESIGN-32-1-7    NaN     NaN
# ...       ...         ...          ...              ...    ...     ...
# 5208     SAV          158           LC    0-CHID-00-1-1    NaN     NaN
# 5209     KNE          130           LC    0-CHID-00-1-1    NaN     NaN
# 5210     ADMC    BHS107             LC  2-TBIOMD-00-1-5    NaN     NaN
# 5211     JOY          106           LC  2-TBIOMD-00-1-5    NaN     NaN
# 5212     ADMC    BHS107             LC  2-TBIOMD-00-1-5    NaN     NaN
# 5213     JOY          106           LC  2-TBIOMD-00-1-5    NaN     NaN
# 5214     JOY          113           LC    2-TPRE-00-0-0    NaN     NaN
# 5215     DOU          280           LC    2-TPRE-00-0-0    NaN     NaN
# 5216     JOY          113           LC    2-TPRE-00-0-0    NaN     NaN
# 5217     DOU          280           LC    2-TPRE-00-0-0    NaN     NaN
# 5218     JOY          113           LC    2-TPRE-00-0-0    NaN     NaN
# 5219     DOU          280           LC    2-TPRE-00-0-0    NaN     NaN
# 5220     THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 5221     KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 5222     THO          334           LC  0-PREMAJ-00-0-0    NaN     NaN
# 5223     KNE          130           LC  0-PREMAJ-00-0-0    NaN     NaN
# 5224     MEB          245           LC  0-PRENUR-00-0-0    NaN     NaN
# 5225     HST     T625               LC  0-PRENUR-00-0-0    NaN     NaN
# 5226     MEB          245           LC  0-PRENUR-00-0-0    NaN     NaN
# 5227     HST     T625               LC  0-PRENUR-00-0-0    NaN     NaN
# 5228     MEB          245           LC  0-PRENUR-00-0-0    NaN     NaN
# 5229     HST     T625               LC  0-PRENUR-00-0-0    NaN     NaN
# 5230     MEB          245           LC  0-PRENUR-00-0-0    NaN     NaN
# 5231     HST     T625               LC  0-PRENUR-00-0-0    NaN     NaN
# 5232     LOW          117           LC   0-PSOCS-00-0-0    NaN     NaN
# 5233     KNE          220           LC   0-PSOCS-00-0-0    NaN     NaN
# 5234     LOW          117           LC   0-PSOCS-00-0-0    NaN     NaN
# 5235     KNE          220           LC   0-PSOCS-00-0-0    NaN     NaN
# 5236     KNE          220           LC   0-PSOCS-00-0-0    NaN     NaN
# 5237     SIG          224           SM   0-PSOCS-00-0-0    NaN     NaN
#
# [5238 rows x 19 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-80-50d283eebbb3> in <module>()
# ----> 1 import arcpy
#
# ModuleNotFoundError: No module named 'arcpy'
